# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
class SinglyLinkedList:
    def __init__(self):
        self.head = None
        
    def append(self, value):
        if not self.head:
            self.head = Node(value)
            
        else:
            current = self.head
            while current.next:              # while current.next !=None
                current = current.next
            current.next = Node(value)
            
            
    def insert(self, index, value):
        if not self.head:
            self.head = Node(value)
            
        elif index <= 0:
            new_node = Node(value)
            new_node.next = self.head
            self.head = new_node
            
        else:
            prev = None
            current = self.head
            counter = 0
            while current.next and counter != index:
                prev = current
                current = current.next
                counter += 1
            if counter != index:
                current.next = Noda(value)
            else:
                new_node = Node(value)
                prev.next = new_node
                new_node.next = current
                
    def remove(self, value):
        current = self.head
        if current.data == value:   #This is O(1)
            self.head = current.next
        else:
            prev_node = None
            while current.next and current.data != value: #worst-case (Avg-case) is O(n)
                prev_node = current
                current = current.next
            if current.data == value:
                prev_node.next = current.next
            else:
                return ValueError("not a list")
            
    def __str__(self):
        out_str = "["
        current = self.head
        while current.next:
            out_str += "%s, " % repr(current.data)
            current = current.next
        out_str += "%s]" % str(current.data)
        return out_str

# %%
mylist = [0, 1, 2, 3, 4]

sll = SinglyLinkedList()

for i in range(5):
    sll.append(i)
    
mylist.insert(2, "new")
sll.insert(2, "new")

sll.remove(0)


print(sll)
print(mylist[2])
# Out:
# [1, 'new', 2, 3, 4]
# new

# %%
#DoableLinkedList
class Dnode:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
    def __str__(self):
        if self.data:
            return self.data__str__()
        else:
            return 'Empty Node'
class DoublyLinkedList:
    def __init__(self):
        self.head == None
        
    def append(self, value):
        new_node = Dnode(value)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current
            
    def insert(self, prev_node, value):
        if prev_node == None:
            print("No previous node.")
            return
        new_node = Dnode(value)
        new_node.next = prev_node.next
        prev_node.next = new_node
        new_node.prev = prev_node
        if new_node.next:
            new_node.next.prev = new_node
            
    def remove(self, value):
        if self.head == None:
            return
        if self.head == value:
            self.head = value.next
        if value.next != None:
            value.next.prev = value.prev
        if value.prev != None:
            value.prev.next = value.next
